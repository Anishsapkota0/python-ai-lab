# %%
x=1 
y=2

# %%
sum=x+y

# %%
print(sum)
# Out:
# 3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=1.2

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
print(id(x))        #id gives memory address
# Out:
# 4424894960

# %%
r="i am a python developer. 
icode in python."
# Out:
#   Cell In[9], line 1
#     r="i am a python developer.
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
r="""i am a pyhton developer and 
i code in python"""

# %%
print(type(r))
# Out:
# <class 'str'>

# %%
print(r)
# Out:
# i am a pyhton developer and
# i code in python

# %%
#boolean 
x=False
print(x,",",type(x))
# Out:
# False , <class 'bool'>

# %%
#None datatypes
x=None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
#list 
x=[1,2,3,4]
print(x,",",type(x))
# Out:
# [1, 2, 3, 4] , <class 'list'>

# %%
#tuples
x=(5,6,7,8)
print(x,",", type(x))
# Out:
# (5, 6, 7, 8) , <class 'tuple'>

# %%
#set 
x={1,2,3,4}
print(type(x))
# Out:
# <class 'set'>

# %%
#dictionary
x={
    "name":"ram",
    "age": 22,
    "contact":"9868828797"
}
print(x,",",type(x))
# Out:
# {'name': 'ram', 'age': 22, 'contact': '9868828797'} , <class 'dict'>

# %%
x=int(input("enter the value of x"))
y=int(input("Enter the value of y"))
sum=x+y
print(f"""The sum of {x} and {y} is """,sum)
# Out:
# enter the value of x 1
# Enter the value of y 1
# The sum of 1 and 1 is  2

# %%
l=int(input("enter the length of rectangle"))
b=int(input("Ente the breadth of rectangle"))
area=l*b
perimeter=2*(l+b)
print("the area of rectangle with length ",l," and breadth ",b,"is ",area)
print("the perimeter of rectangle with length ",l," and breadth ",b,"is ",perimeter)
# Out:
# enter the length of rectangle 3
# Ente the breadth of rectangle 5
# the area of rectangle with length  3  and breadth  5 is  15
# the perimeter of rectangle with length  3  and breadth  5 is  16

# %%
2 != 5
# Out:
# True

# %%
5>=5
# Out:
# True

# %%
name = "My name is anish sapkota"

# %%
print("the length of string ",name,"is ",len(name))
# Out:
# the length of string  My name is anish sapkota is  24

# %%
len('apple') == len("banana")
# Out:
# False
