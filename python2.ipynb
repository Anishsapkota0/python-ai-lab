# %%
name ="ramesh"

# %%
print(len(name))
# Out:
# 6

# %%
#logical operator
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
not False
# Out:
# True

# %%
False and False
# Out:
# False

# %%
not not True
# Out:
# True

# %%
True or False and True
# Out:
# True

# %%
# precedence
# small bracket
# and 
# or
(True or False) and True
# Out:
# True

# %%
#membership Operator
1 in [2,3,4,5,6]
# Out:
# False

# %%
'r' or 'h' in "ramesh"
# Out:
# 'r'

# %%
s="This is string. Strings in python are immutable"

# %%
s[-1] #negative indexing
# Out:
# 'e'

# %%
s[0:4] #slicing
# Out:
# 'This'

# %%
s[0:]
# Out:
# 'This is string. Strings in python are immutable'

# %%
print(len(s))
# Out:
# 47

# %%
print(s[:48])
# Out:
# This is string. Strings in python are immutable

# %% [raw]
# print(s[0:14:3])

# %%
print(s[0:14:3])
# Out:
# Tsstn

# %%
print(s[-1:])

# %%
print(s[-12:-1])
# Out:
# re immutabl

# %%
print(s[-1::-1])
# Out:
# elbatummi era nohtyp ni sgnirtS .gnirts si sihT

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
s.casefold()
# Out:
# 'this is string. strings in python are immutable'

# %%
s.upper()
# Out:
# 'THIS IS STRING. STRINGS IN PYTHON ARE IMMUTABLE'

# %%
s.title()
# Out:
# 'This Is String. Strings In Python Are Immutable'

# %%
x="     my name is anish sapkota      "

# %%
print(x)
# Out:
#      my name is anish sapkota

# %%
x.strip()
# Out:
# 'my name is anish sapkota'

# %%
y="ram->hari->sita"

# %%
x=y.split('->')

# %%
print(x)
# Out:
# ['ram', 'hari', 'sita']

# %%
z="+".join(x)

# %%
print(z)
# Out:
# ram+hari+sita

# %%
#list support any kind of data structure

# %%
x=[1,1.5,"ram",5j,{1,2,3},("ram","shyam","Hari"),{"name":"anish","email":"anishsapkota265@gmail.com","contact":"9868828797"}]

# %%
print(x)
# Out:
# [1, 1.5, 'ram', 5j, {1, 2, 3}, ('ram', 'shyam', 'Hari'), {'name': 'anish', 'email': 'anishsapkota265@gmail.com', 'contact': '9868828797'}]

# %%
fruits=['apple',"orange","""banana""","mango"]

# %%
fruits[2]
# Out:
# 'banana'

# %%
fruits[-1]
# Out:
# 'mango'

# %%
fruits[-3:-1]
# Out:
# ['orange', 'banana']

# %%
fruits[::2]
# Out:
# ['apple', 'banana']

# %%
x=[1,2,[3,4,5,6],7,8]

# %%
x[2][0]
# Out:
# 3
