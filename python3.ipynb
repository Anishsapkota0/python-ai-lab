# %%
fruits = ["banana","apple","mango","orange","litchi"]

# %%
fruits[0]="ram"

# %%
print(fruits)
# Out:
# ['ram', 'apple', 'mango', 'orange', 'litchi']

# %%
del fruits[0]

# %%
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'litchi']

# %%
fruits.append("grapes")

# %%
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'litchi', 'grapes']

# %%
#fruits.clear()
[]
# Out:
# []

# %%
fruits.insert(1,"banana")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'litchi', 'grapes']

# %%
fruits.pop()
# Out:
# 'grapes'

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'litchi']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits.push(0,"apple")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fruits.push(0,"apple")
#
# AttributeError: 'list' object has no attribute 'push'
